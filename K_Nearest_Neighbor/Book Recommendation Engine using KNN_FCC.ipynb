# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Ratings = pd.read_csv('BX-Book-Ratings.csv', on_bad_lines='skip', sep=';', encoding='ISO-8859-1', header = 0, names=['user', 'isbn', 'rating'], usecols=['user', 'isbn', 'rating'], dtype={'user': 'int32', 'isbn': 'str', 'rating': 'float32'})
Books = pd.read_csv('BX-Books.csv', on_bad_lines='skip', sep=';', encoding='ISO-8859-1', header = 0,  names=['isbn', 'title', 'author'], usecols=['isbn', 'title', 'author'], dtype={'isbn': 'str', 'title': 'str', 'author': 'str'})
Users = pd.read_csv('BX-Users.csv', sep=';', encoding='ISO-8859-1')

# %%
Ratings.head()
# Out:
#      user        isbn  rating
# 0  276725  034545104X     0.0
# 1  276726  0155061224     5.0
# 2  276727  0446520802     0.0
# 3  276729  052165615X     3.0
# 4  276729  0521795028     6.0

# %%
Ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   user    1149780 non-null  int32
#  1   isbn    1149780 non-null  object
#  2   rating  1149780 non-null  float32
# dtypes: float32(1), int32(1), object(1)
# memory usage: 17.5+ MB

# %%
Ratings['isbn'] = Ratings['isbn'].astype('string')
Ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   user    1149780 non-null  int32
#  1   isbn    1149780 non-null  string
#  2   rating  1149780 non-null  float32
# dtypes: float32(1), int32(1), string(1)
# memory usage: 17.5 MB

# %%
Ratings['isbn'].duplicated().value_counts()
# Out:
# isbn
# True     809224
# False    340556
# Name: count, dtype: int64

# %%
Ratings['user'].duplicated().value_counts()
# Out:
# user
# True     1044497
# False     105283
# Name: count, dtype: int64

# %%
Books.head()
# Out:
#          isbn                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author
# 0    Mark P. O. Morford
# 1  Richard Bruce Wright
# 2          Carlo D'Este
# 3      Gina Bari Kolata
# 4       E. J. W. Barber

# %%
Books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271379 entries, 0 to 271378
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   isbn    271379 non-null  object
#  1   title   271379 non-null  object
#  2   author  271377 non-null  object
# dtypes: object(3)
# memory usage: 6.2+ MB

# %%
Books['isbn'] = Books['isbn'].astype('string')
Books['title'] = Books['title'].astype('string')
Books['author'] = Books['author'].astype('string')
Books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271379 entries, 0 to 271378
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   isbn    271379 non-null  string
#  1   title   271379 non-null  string
#  2   author  271377 non-null  string
# dtypes: string(3)
# memory usage: 6.2 MB

# %%
Users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
Users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278858 entries, 0 to 278857
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   User-ID   278858 non-null  int64
#  1   Location  278858 non-null  object
#  2   Age       168096 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 6.4+ MB

# %%
print('Shape of Books:', Books.shape)
print('Shape of Ratings:', Ratings.shape)
print('Shape of Users:', Users.shape)
# Out:
# Shape of Books: (271379, 3)
# Shape of Ratings: (1149780, 3)
# Shape of Users: (278858, 3)

# %% [markdown]
# Merging dataframes

# %%
df = Ratings.merge(Books, on='isbn', how='left')

# %%
df.head()
# Out:
#      user        isbn  rating  \
# 0  276725  034545104X     0.0
# 1  276726  0155061224     5.0
# 2  276727  0446520802     0.0
# 3  276729  052165615X     3.0
# 4  276729  0521795028     6.0
#
#                                                title           author
# 0                               Flesh Tones: A Novel       M. J. Rose
# 1                                   Rites of Passage       Judith Rae
# 2                                       The Notebook  Nicholas Sparks
# 3                                     Help!: Level 1    Philip Prowse
# 4  The Amsterdam Connection : Level 4 (Cambridge ...      Sue Leather

# %%
df['user'].value_counts()
# Out:
# user
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: count, Length: 105283, dtype: int64

# %%
df['isbn'].value_counts()
# Out:
# isbn
# 0971880107     2502
# 0316666343     1295
# 0385504209      883
# 0060928336      732
# 0312195516      723
#                ...
# 1561443042        1
# 1561446815        1
# 1561562262        1
# 0451406192        1
# 05162443314       1
# Name: count, Length: 340556, dtype: Int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   user    1149780 non-null  int32
#  1   isbn    1149780 non-null  string
#  2   rating  1149780 non-null  float32
#  3   title   1031175 non-null  string
#  4   author  1031173 non-null  string
# dtypes: float32(1), int32(1), string(3)
# memory usage: 35.1 MB

# %%
user_over_200 = df['user'].value_counts()
user_over_200 = user_over_200[user_over_200 > 200].index

# %%
isbn_over_100 = df['isbn'].value_counts()
isbn_over_100 = isbn_over_100[isbn_over_100 > 100].index

# %%
ready_df = df.loc[df['user'].isin(user_over_200) & df['isbn'].isin(isbn_over_100)]
ready_df.head()
# Out:
#         user        isbn  rating  \
# 1456  277427  002542730X    10.0
# 1469  277427  0060930535     0.0
# 1471  277427  0060934417     0.0
# 1474  277427  0061009059     9.0
# 1484  277427  0140067477     0.0
#
#                                                   title              author
# 1456  Politically Correct Bedtime Stories: Modern Ta...   James Finn Garner
# 1469                      The Poisonwood Bible: A Novel  Barbara Kingsolver
# 1471                                 Bel Canto: A Novel        Ann Patchett
# 1474  One for the Money (Stephanie Plum Novels (Pape...     Janet Evanovich
# 1484                                    The Tao of Pooh       Benjamin Hoff

# %%
ready_df[['title', 'user']].duplicated().value_counts()
# Out:
# False    48853
# True       401
# Name: count, dtype: int64

# %%
ready_df = ready_df.drop_duplicates(['user', 'title'])
ready_df.head()
# Out:
#         user        isbn  rating  \
# 1456  277427  002542730X    10.0
# 1469  277427  0060930535     0.0
# 1471  277427  0060934417     0.0
# 1474  277427  0061009059     9.0
# 1484  277427  0140067477     0.0
#
#                                                   title              author
# 1456  Politically Correct Bedtime Stories: Modern Ta...   James Finn Garner
# 1469                      The Poisonwood Bible: A Novel  Barbara Kingsolver
# 1471                                 Bel Canto: A Novel        Ann Patchett
# 1474  One for the Money (Stephanie Plum Novels (Pape...     Janet Evanovich
# 1484                                    The Tao of Pooh       Benjamin Hoff

# %%
ready_df_p = ready_df.pivot_table(index= 'title', columns='user', values='rating').fillna(0)
ready_df_p
# Out:
# user                                                254     2276    2766    \
# title
# 1984                                                   9.0     0.0     0.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2nd Chance                                             0.0    10.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# A Beautiful Mind: The Life of Mathematical Geni...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Without Remorse                                        0.0     0.0     0.0
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix

# %%
df_knn = csr_matrix(ready_df_p.values)

# %% [markdown]
# Machine Learing calssification

# %%
from sklearn.neighbors import NearestNeighbors

# %%
knn = NearestNeighbors(metric='cosine', algorithm='brute')
knn.fit(df_knn)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
def get_recommends(book=""):
    recommended_books = [book, []]
    
    distances, indices = knn.kneighbors([ready_df_p.loc[book]], 6, return_distance=True)
    
    recommended_indices = ready_df_p.iloc[np.flip(indices[0])[:-1]].index.to_list()
    recommended_distances = list(np.flip(distances[0])[:-1])
    
    for i in zip(recommended_indices, recommended_distances):
        recommended_books[1].append(list(i))

    return recommended_books

# %%
books = get_recommends("Where the Heart Is (Oprah's Book Club (Paperback))")
print(books)

def test_book_recommendation():
  test_pass = True
  recommends = get_recommends("Where the Heart Is (Oprah's Book Club (Paperback))")
  if recommends[0] != "Where the Heart Is (Oprah's Book Club (Paperback))":
    test_pass = False
  recommended_books = ["I'll Be Seeing You", 'The Weight of Water', 'The Surgeon', 'I Know This Much Is True']
  recommended_books_dist = [0.8, 0.77, 0.77, 0.77]
  for i in range(2): 
    if recommends[1][i][0] not in recommended_books:
      test_pass = False
    if abs(recommends[1][i][1],recommended_books_dist[i]) >= 0.05:
      test_pass = False
  if test_pass:
    print("You passed the challenge! 🎉🎉🎉🎉🎉")
  else:
    print("You haven't passed yet. Keep trying!")

test_book_recommendation()
# Out:
# ["Where the Heart Is (Oprah's Book Club (Paperback))", [["I'll Be Seeing You", 0.8016211], ['The Weight of Water', 0.77085835], ['The Surgeon', 0.7699411], ['I Know This Much Is True', 0.7677075], ['The Lovely Bones: A Novel', 0.7230184]]]
# You passed the challenge! 🎉🎉🎉🎉🎉

# %% [markdown]
# Function to get recommended books:

# %%
books = get_recommends("The Weight of Water")
print(books)
# Out:
# ['The Weight of Water', [["Smilla's Sense of Snow", 0.71307], ['Night', 0.7105186], ['Deja Dead', 0.7087431], ["The Dive From Clausen's Pier (Alex Awards)", 0.68558145], ['Gap Creek: The Story Of A Marriage', 0.6642004]]]

# %%
print('Enter the book name to find recommendations: ')
x = input("")

recommended_books = get_recommends(x)

recommended_books_list = [f"{book} (distance: {dist:.2f})" for book, dist in recommended_books[1]]

print('Recommended books for ' + x + ': ' + ', '.join(recommended_books_list))
# Out:
# Enter the book name to find recommendations:
# Recommended books for Night: The Hundred Secret Senses (distance: 0.74), Let Me Call You Sweetheart (distance: 0.74), Degree of Guilt (distance: 0.72), Before I Say Good-Bye (distance: 0.71), The Weight of Water (distance: 0.71)
