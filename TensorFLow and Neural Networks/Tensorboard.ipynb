# %%
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('cancer_classification.csv')

# %%
data.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  benign_0__mal_1
# 0          0.4601                  0.11890                0
# 1          0.2750                  0.08902                0
# 2          0.3613                  0.08758                0
# 3          0.6638                  0.17300                0
# 4          0.2364                  0.07678                0
#
# [5 rows x 31 columns]

# %%
X = data.drop('benign_0__mal_1',axis=1).values
y = data['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout
from tensorflow.keras.callbacks import EarlyStopping,TensorBoard
# Out:
# 2024-06-22 12:30:11.492241: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
stop = EarlyStopping(monitor='val_loss', mode='mean', verbose=1, patience=25)
# Out:
# /var/folders/yk/fs7s5htj44b8ds6qh_c6gb0m0000gn/T/ipykernel_17714/2485216245.py:1: UserWarning: EarlyStopping mode mean is unknown, fallback to auto mode.
#   stop = EarlyStopping(monitor='val_loss', mode='mean', verbose=1, patience=25)

# %%
pwd
# Out:
# '/Users/bartlomiejszafran/Desktop/VS CODE'

# %%
from datetime import datetime

# %%
datetime.now().strftime("%Y-%m-%d--%H%M")
# Out:
# '2024-06-22--1235'

# %%
log_directory = "logs/fit"
timestamp = datetime.now().strftime("%Y-%m-%d--%H%M")
log_directory = log_directory + '/' + timestamp

# %%
board = TensorBoard(log_dir=log_directory,histogram_freq=1,
    write_graph=True,
    write_images=True,
    update_freq='epoch',
    profile_batch=2,
    embeddings_freq=1)
# Out:
# 2024-06-22 12:39:05.435606: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2024-06-22 12:39:05.436892: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2024-06-22 12:39:05.448147: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.

# %%
model = Sequential()
model.add(Dense(units=30,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=15,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
model.fit(x=X_train, 
          y=y_train, 
          epochs=600,
          validation_data=(X_test, y_test), verbose=1,
          callbacks=[stop,board]
          )
# Out:
# Epoch 1/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step,loss: 0.6663
# 2024-06-22 12:39:43.805120: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:104] Profiler session initializing.
# 2024-06-22 12:39:43.805138: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:119] Profiler session started.
# 2024-06-22 12:39:43.815693: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:70] Profiler session collecting data.
# 2024-06-22 12:39:43.824366: I external/local_tsl/tsl/profiler/lib/profiler_session.cc:131] Profiler session tear down.
# 2024-06-22 12:39:43.833030: I external/local_tsl/tsl/profiler/rpc/client/save_profile.cc:144] Collecting XSpace to repository: logs/fit/2024-06-22--1238/plugins/profile/2024_06_22_12_39_43/MacBook-Pro-Bartlomiej.local.xplane.pb
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step,loss: 0.6667,val_loss: 0.6406
# Epoch 2/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.6664,val_loss: 0.6214
# Epoch 3/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.6198,val_loss: 0.6040
# Epoch 4/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.6380,val_loss: 0.5873
# Epoch 5/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step,loss: 0.6156,val_loss: 0.5649
# Epoch 6/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step,loss: 0.5970,val_loss: 0.5363
# Epoch 7/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.5864,val_loss: 0.5070
# Epoch 8/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.5183,val_loss: 0.4758
# Epoch 9/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.5152,val_loss: 0.4449
# Epoch 10/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.4895,val_loss: 0.4170
# Epoch 11/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.4781,val_loss: 0.3905
# Epoch 12/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step,loss: 0.4320,val_loss: 0.3650
# Epoch 13/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.4128,val_loss: 0.3454
# Epoch 14/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.4479,val_loss: 0.3289
# Epoch 15/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.4352,val_loss: 0.3157
# Epoch 16/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.3848,val_loss: 0.2938
# Epoch 17/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step,loss: 0.4023,val_loss: 0.2790
# Epoch 18/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.3865,val_loss: 0.2640
# Epoch 19/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step,loss: 0.3078,val_loss: 0.2476
# Epoch 20/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.3324,val_loss: 0.2361
# Epoch 21/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step,loss: 0.3358,val_loss: 0.2287
# Epoch 22/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.3006,val_loss: 0.2207
# Epoch 23/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.3265,val_loss: 0.2204
# Epoch 24/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step,loss: 0.3111,val_loss: 0.2064
# Epoch 25/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.2675,val_loss: 0.1995
# Epoch 26/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.2817,val_loss: 0.1953
# Epoch 27/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.2948,val_loss: 0.1835
# Epoch 28/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step,loss: 0.2625,val_loss: 0.1719
# Epoch 29/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.2466,val_loss: 0.1709
# Epoch 30/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.2336,val_loss: 0.1677
# Epoch 31/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step,loss: 0.2248,val_loss: 0.1636
# Epoch 32/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step,loss: 0.2646,val_loss: 0.1570
# Epoch 33/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.2198,val_loss: 0.1534
# Epoch 34/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.2627,val_loss: 0.1566
# Epoch 35/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.2681,val_loss: 0.1502
# Epoch 36/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.1920,val_loss: 0.1451
# Epoch 37/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.1909,val_loss: 0.1446
# Epoch 38/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.1918,val_loss: 0.1420
# Epoch 39/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step,loss: 0.1781,val_loss: 0.1370
# Epoch 40/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.2093,val_loss: 0.1363
# Epoch 41/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.2040,val_loss: 0.1293
# Epoch 42/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.2019,val_loss: 0.1339
# Epoch 43/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step,loss: 0.1794,val_loss: 0.1259
# Epoch 44/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.1669,val_loss: 0.1208
# Epoch 45/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step,loss: 0.1723,val_loss: 0.1194
# Epoch 46/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.2516,val_loss: 0.1196
# Epoch 47/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step,loss: 0.1489,val_loss: 0.1154
# Epoch 48/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step,loss: 0.1607,val_loss: 0.1183
# Epoch 49/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step,loss: 0.1514,val_loss: 0.1215
# Epoch 50/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step,loss: 0.1575,val_loss: 0.1170
# Epoch 51/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step,loss: 0.1961,val_loss: 0.1137
# Epoch 52/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step,loss: 0.1446,val_loss: 0.1218
# Epoch 53/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step,loss: 0.1682,val_loss: 0.1082
# Epoch 54/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step,loss: 0.2057,val_loss: 0.1102
# Epoch 55/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/
600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.1117,val_loss: 0.1002
# Epoch 107/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.0840,val_loss: 0.0934
# Epoch 108/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.1031,val_loss: 0.0878
# Epoch 109/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step,loss: 0.1026,val_loss: 0.0903
# Epoch 110/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step,loss: 0.1231,val_loss: 0.0980
# Epoch 111/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.1299,val_loss: 0.0830
# Epoch 112/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step,loss: 0.1019,val_loss: 0.0931
# Epoch 113/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.1150,val_loss: 0.0945
# Epoch 114/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.0982,val_loss: 0.0952
# Epoch 115/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.0908,val_loss: 0.0895
# Epoch 116/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step,loss: 0.0708,val_loss: 0.1054
# Epoch 117/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step,loss: 0.0941,val_loss: 0.0941
# Epoch 118/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.1138,val_loss: 0.0953
# Epoch 119/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.0932,val_loss: 0.0997
# Epoch 120/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.0959,val_loss: 0.0894
# Epoch 121/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.1165,val_loss: 0.1028
# Epoch 122/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step,loss: 0.0867,val_loss: 0.0955
# Epoch 123/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.0905,val_loss: 0.0981
# Epoch 124/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.0768,val_loss: 0.1061
# Epoch 125/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.1113,val_loss: 0.0943
# Epoch 126/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.0747,val_loss: 0.1107
# Epoch 127/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.1026,val_loss: 0.0932
# Epoch 128/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.0965,val_loss: 0.0810
# Epoch 129/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step,loss: 0.1195,val_loss: 0.0876
# Epoch 130/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.0783,val_loss: 0.0975
# Epoch 131/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step,loss: 0.1091,val_loss: 0.0892
# Epoch 132/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.0897,val_loss: 0.0880
# Epoch 133/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step,loss: 0.0989,val_loss: 0.0995
# Epoch 134/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.0717,val_loss: 0.0889
# Epoch 135/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.0740,val_loss: 0.0837
# Epoch 136/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.0908,val_loss: 0.0999
# Epoch 137/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.0743,val_loss: 0.1033
# Epoch 138/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.0593,val_loss: 0.0955
# Epoch 139/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step,loss: 0.0812,val_loss: 0.0938
# Epoch 140/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.0800,val_loss: 0.0955
# Epoch 141/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.1096,val_loss: 0.0985
# Epoch 142/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.0946,val_loss: 0.1012
# Epoch 143/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.0611,val_loss: 0.0899
# Epoch 144/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.0688,val_loss: 0.0953
# Epoch 145/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.0752,val_loss: 0.0993
# Epoch 146/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step,loss: 0.1088,val_loss: 0.0991
# Epoch 147/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step,loss: 0.0781,val_loss: 0.0821
# Epoch 148/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step,loss: 0.0720,val_loss: 0.0879
# Epoch 149/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step,loss: 0.1062,val_loss: 0.0997
# Epoch 150/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step,loss: 0.0817,val_loss: 0.0950
# Epoch 151/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.0848,val_loss: 0.1079
# Epoch 152/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step,loss: 0.0881,val_loss: 0.0880
# Epoch 153/600
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step,loss: 0.0846,val_loss: 0.0940
# Epoch 153: early stopping

# %%
print(log_directory)
# Out:
# logs/fit/2024-06-22--1238

# %%
pwd
# Out:
# '/Users/bartlomiejszafran/Desktop/VS CODE'
